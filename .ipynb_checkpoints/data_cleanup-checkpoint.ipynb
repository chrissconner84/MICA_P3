# %%
#dependencies

from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

import seaborn as sns
# %matplotlib inline

# import datetime
# from dateutil.relativedelta import relativedelta
# from datetime import date

#import re
#import nltk
#from nltk.corpus import stopwords

# %%
# Read in csv's

temp_us = "..//practice_sources/US_youtube_trending_data.csv"
temp_br = "..//practice_sources/BR_youtube_trending_data.csv"
temp_ca = "..//practice_sources/CA_youtube_trending_data.csv"
temp_de = "..//practice_sources/DE_youtube_trending_data.csv"
temp_fr = "..//practice_sources/FR_youtube_trending_data.csv"
temp_gb = "..//practice_sources/GB_youtube_trending_data.csv"
temp_in = "..//practice_sources/IN_youtube_trending_data.csv"
temp_jp = "..//practice_sources/JP_youtube_trending_data.csv"
temp_kr = "..//practice_sources/KR_youtube_trending_data.csv"
temp_mx = "..//practice_sources/MX_youtube_trending_data.csv"
temp_ru = "..//practice_sources/RU_youtube_trending_data.csv"

us_df = pd.read_csv(temp_us)
br_df = pd.read_csv(temp_br)
ca_df = pd.read_csv(temp_ca)
de_df = pd.read_csv(temp_de)
fr_df = pd.read_csv(temp_fr)
gb_df = pd.read_csv(temp_gb)
in_df = pd.read_csv(temp_in)
jp_df = pd.read_csv(temp_jp)
kr_df = pd.read_csv(temp_kr)
mx_df = pd.read_csv(temp_mx)
ru_df = pd.read_csv(temp_ru)

# %%
# Add country string column

us_df['country'] = 'United States'
br_df['country'] = 'Brazil'
ca_df['country'] = 'Canada'
de_df['country'] = 'Germany'
fr_df['country'] = 'France'
gb_df['country'] = 'United Kingdom'
in_df['country'] = 'India'
jp_df['country'] = 'Japan'
kr_df['country'] = 'South Korea'
mx_df['country'] = 'Mexico'
ru_df['country'] = 'Russia'

# %%
# Updating categoryId column with corresponding string for all csv's

category_codes = {
    "1":'Film & Animation',
    "2":'Autos & Vehicles',
    "10":'Music',
    "15":'Pets & Animals',
    "17":'Sports',
    "18":'Short Movies',
    "19":'Travel & Events',
    "20":'Gaming',
    "21":'Videoblogging',
    "22":'People & Blogs',
    "23":'Comedy',
    "24":'Entertainment',
    "25":'News & Politics',
    "26":'Howto & Style',
    "27":'Education',
    "28":'Science & Technology',
    "29":'Nonprofits & Activism',
    "30":'Movies',
    "31":'Anime/Animation',
    "32":'Action/Adventure',
    "33":'Classics',
    "34":'Comedy',
    "35":'Documentary',
    "36":'Drama',
    "37":'Family',
    "38":'Foreign',
    "39":'Horror',
    "40":'Sci-Fi/Fantasy',
    "41":'Thriller',
    "42":'Shorts',
    "43":'Shows',
    "44":'Trailers'
}

cat_code = us_df["categoryId"].map(lambda x: category_codes[str(x)])
us_df['cat_codes'] = cat_code

cat_code = br_df["categoryId"].map(lambda x: category_codes[str(x)])
br_df['cat_codes'] = cat_code

cat_code = ca_df["categoryId"].map(lambda x: category_codes[str(x)])
ca_df['cat_codes'] = cat_code

cat_code = de_df["categoryId"].map(lambda x: category_codes[str(x)])
de_df['cat_codes'] = cat_code

cat_code = fr_df["categoryId"].map(lambda x: category_codes[str(x)])
fr_df['cat_codes'] = cat_code

cat_code = gb_df["categoryId"].map(lambda x: category_codes[str(x)])
gb_df['cat_codes'] = cat_code

cat_code = in_df["categoryId"].map(lambda x: category_codes[str(x)])
in_df['cat_codes'] = cat_code

cat_code = jp_df["categoryId"].map(lambda x: category_codes[str(x)])
jp_df['cat_codes'] = cat_code

cat_code = kr_df["categoryId"].map(lambda x: category_codes[str(x)])
kr_df['cat_codes'] = cat_code

cat_code = mx_df["categoryId"].map(lambda x: category_codes[str(x)])
mx_df['cat_codes'] = cat_code

cat_code = ru_df["categoryId"].map(lambda x: category_codes[str(x)])
ru_df['cat_codes'] = cat_code

# %%
#concat all 11 csv's

ind_dfs = [us_df, br_df, ca_df, de_df, fr_df, gb_df, in_df, jp_df, kr_df, mx_df, ru_df]
main_df = pd.concat(ind_dfs)

# %%
# remove unwanted pipes from tags with .split()

def split_tags(tag):
    if tag == '[none]': return []
    return tag.lower().replace('"','').split('|')

main_df['tags'] = main_df['tags'].apply(split_tags)

# %%
# drop uneeded columns

main_df.drop(['comments_disabled', 'ratings_disabled'], axis = 1, inplace = True)

# %%
#drop uneeded columns

main_df.drop(['video_id', 'channelId'], axis = 1, inplace = True)

# %%
# clean title column in order to make word cloud

# def scrubbed_titles(title):
#     lower_split = title.lower().split()
#     clean = []
#     remove_words = set(stopwords.words('english'))
#     for scrubbed in lower_split:
#         if scrubbed.startswith('$') or scrubbed.isnumeric() or not scrubbed.isalnum() or scrubbed in remove_words:
#             continue
#         else:
#             scrubbed.append(scrubbed)
#     return ' '.join(clean)

# main_df['title_split'] = main_df['title'].apply(scrubbed_titles)

# %%
############   STARTING DATAFRAME    ##############

main_df
# Out:
#                                                     title  \
# 0                      I ASKED HER TO BE MY GIRLFRIEND...
# 1       Apex Legends | Stories from the Outlands – “Th...
# 2       I left youtube for a month and THIS is what ha...
# 3       XXL 2020 Freshman Class Revealed - Official An...
# 4       Ultimate DIY Home Movie Theater for The LaBran...
# ...                                                   ...
# 117568                        Эту песню поёт Оля Бузова?😂
# 117569      Сериал След. «Убийство по учебнику» Премьера!
# 117570                           Прямой эфир | 24.03.2022
# 117571                  ✅ПАЖИЛОЙ ВЗВОД ДЕДУШЕК НА КВ-2🔥😎💪
# 117572  Тёмное прошлое Дмитрия Гордона ! Как выглядит ...
#
#                  publishedAt                channelTitle  categoryId  \
# 0       2020-08-11T19:20:14Z                    Brawadis          22
# 1       2020-08-11T17:00:10Z                Apex Legends          20
# 2       2020-08-11T16:34:06Z               jacksepticeye          24
# 3       2020-08-11T16:38:55Z                         XXL          10
# 4       2020-08-11T15:10:05Z                    Mr. Kate          26
# ...                      ...                         ...         ...
# 117568  2022-03-24T11:07:58Z                       ХАБИБ          10
# 117569  2022-03-24T11:00:29Z                Сериал След.           1
# 117570  2022-03-24T20:08:26Z  ABU-SADDAM SHISHANI [LIVE]          22
# 117571  2022-03-24T07:00:07Z                   Artyashka          20
# 117572  2022-03-25T04:00:09Z           АМЕРИКА Наизнанку          22
#
#                trending_date  \
# 0       2020-08-12T00:00:00Z
# 1       2020-08-12T00:00:00Z
# 2       2020-08-12T00:00:00Z
# 3       2020-08-12T00:00:00Z
# 4       2020-08-12T00:00:00Z
# ...                      ...
# 117568  2022-03-26T00:00:00Z
# 117569  2022-03-26T00:00:00Z
# 117570  2022-03-26T00:00:00Z
# 117571  2022-03-26T00:00:00Z
# 117572  2022-03-26T00:00:00Z
#
#                                                      tags  view_count   likes  \
# 0       [brawadis, prank, basketball, skits, ghost, fu...     1514614  156908
# 1       [apex legends, apex legends characters, new ap...     2381688  146739
# 2       [jacksepticeye, funny, funny meme, memes, jack...     2038853  353787
# 3       [xxl freshman, xxl freshmen, 2020 xxl freshman...      496771   23251
# 4       [the labrant family, diy, interior design, mak...     1123889   45802
# ...                                                   ...         ...     ...
# 117568                                           [[none]]      666886   44566
# 117569  [след, сериал след, след новый сезон, смотреть...      257324    5266
# 117570  [тумсо, абдурахманов, абу саддам, шишани, чечн...       86225    1982
# 117571  [artyashka, world of tanks, мир танков, wot, т...      103490   10459
# 117572                                           [[none]]      200628   24194
#
#         dislikes  comment_count  \
# 0           5855          35313
# 1           2794          16549
# 2           2628          40221
# 3           1856           7647
# 4            964           2196
# ...          ...            ...
# 117568         0            343
# 117569         0            268
# 117570         0            443
# 117571         0            360
# 117572         0           2914
#
#                                         thumbnail_link  \
# 0       https://i.ytimg.com/vi/3C66w5Z0ixs/default.jpg
# 1       https://i.ytimg.com/vi/M9Pmf9AB4Mo/default.jpg
# 2       https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg
# 3       https://i.ytimg.com/vi/kXLn3HkpjaA/default.jpg
# 4       https://i.ytimg.com/vi/VIUo6yapDbc/default.jpg
# ...                                                ...
# 117568  https://i.ytimg.com/vi/yvl28gDYfiM/default.jpg
# 117569  https://i.ytimg.com/vi/Z1ouOJ89vYI/default.jpg
# 117570  https://i.ytimg.com/vi/HnCmHJDxcYo/default.jpg
# 117571  https://i.ytimg.com/vi/XpcH9FLUR7E/default.jpg
# 117572  https://i.ytimg.com/vi/XY7-8t-BLHs/default.jpg
#
#                                               description        country  \
# 0       SUBSCRIBE to BRAWADIS ▶ http://bit.ly/Subscrib...  United States
# 1       While running her own modding shop, Ramya Pare...  United States
# 2       I left youtube for a month and this is what ha...  United States
# 3       Subscribe to XXL → http://bit.ly/subscribe-xxl...  United States
# 4       Transforming The LaBrant Family's empty white ...  United States
# ...                                                   ...            ...
# 117568                                                NaN         Russia
# 117569  По просьбе Следственного Комитета Федеральная ...         Russia
# 117570  Переходи по ссылке https://surfshark.deals/abu...         Russia
# 117571  ▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬✔️Мой 2-ой канал:...         Russia
# 117572  Мой телеграмм https://t.me/enBoVZYDCEs0NWJi Ст...         Russia
#
#                cat_codes
# 0         People & Blogs
# 1                 Gaming
# 2          Entertainment
# 3                  Music
# 4          Howto & Style
# ...                  ...
# 117568             Music
# 117569  Film & Animation
# 117570    People & Blogs
# 117571            Gaming
# 117572    People & Blogs
#
# [1300295 rows x 14 columns]

# %%
main_df.describe()
# Out:
#          categoryId    view_count         likes      dislikes  comment_count
# count  1.300295e+06  1.300295e+06  1.300295e+06  1.300295e+06   1.300295e+06
# mean   1.933569e+01  1.900843e+06  1.102276e+05  2.067433e+03   9.200871e+03
# std    6.705385e+00  5.999856e+06  3.877723e+05  3.317699e+04   9.082902e+04
# min    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    1.700000e+01  2.429760e+05  8.548000e+03  6.700000e+01   5.360000e+02
# 50%    2.200000e+01  5.911560e+05  2.503000e+04  3.080000e+02   1.483000e+03
# 75%    2.400000e+01  1.512881e+06  7.838250e+04  1.086000e+03   4.339000e+03
# max    2.900000e+01  2.963142e+08  1.646425e+07  1.234147e+07   6.939302e+06

# %%
###  TRYING TO CALCULATE TIME BETWEEN PUBLISH AND TRENDING DATE

# data = {'published': main_df['publishedAt'],
#         'trended': main_df['trending_date']}

# df = pd.DataFrame(data)

#df['diff'] = df['trended'] - df['published']

# %%
main_df.columns
# Out:
# Index(['title', 'publishedAt', 'channelTitle', 'categoryId', 'trending_date',
#        'tags', 'view_count', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'description', 'country', 'cat_codes'],
#       dtype='object')

# %%
# videos by category bar

fig = px.bar(main_df, x ='ca')
# Out:
# C:\Users\mikej\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# dataframe for user behaviors (User Engagement Page)

engagement_df = main_df[['cat_codes', 'country','channelTitle', 'title', 'view_count', 'comment_count', 'likes', 'dislikes']]
engagement_df.head()
# Out:
#         cat_codes        country   channelTitle  \
# 0  People & Blogs  United States       Brawadis
# 1          Gaming  United States   Apex Legends
# 2   Entertainment  United States  jacksepticeye
# 3           Music  United States            XXL
# 4   Howto & Style  United States       Mr. Kate
#
#                                                title  view_count  \
# 0                 I ASKED HER TO BE MY GIRLFRIEND...     1514614
# 1  Apex Legends | Stories from the Outlands – “Th...     2381688
# 2  I left youtube for a month and THIS is what ha...     2038853
# 3  XXL 2020 Freshman Class Revealed - Official An...      496771
# 4  Ultimate DIY Home Movie Theater for The LaBran...     1123889
#
#    comment_count   likes  dislikes
# 0          35313  156908      5855
# 1          16549  146739      2794
# 2          40221  353787      2628
# 3           7647   23251      1856
# 4           2196   45802       964

# %%
# describe engagement dataframe

engagement_df.describe(include = 'all')
# Out:
#             cat_codes         country channelTitle             title  \
# count         1300295         1300295      1300294           1300295
# unique             15              11        33919            244703
# top     Entertainment  United Kingdom    BANGTANTV  Starlink Mission
# freq           339599          119195         2991               402
# mean              NaN             NaN          NaN               NaN
# std               NaN             NaN          NaN               NaN
# min               NaN             NaN          NaN               NaN
# 25%               NaN             NaN          NaN               NaN
# 50%               NaN             NaN          NaN               NaN
# 75%               NaN             NaN          NaN               NaN
# max               NaN             NaN          NaN               NaN
#
#           view_count  comment_count         likes      dislikes
# count   1.300295e+06   1.300295e+06  1.300295e+06  1.300295e+06
# unique           NaN            NaN           NaN           NaN
# top              NaN            NaN           NaN           NaN
# freq             NaN            NaN           NaN           NaN
# mean    1.900843e+06   9.200871e+03  1.102276e+05  2.067433e+03
# std     5.999856e+06   9.082902e+04  3.877723e+05  3.317699e+04
# min     0.000000e+00   0.000000e+00  0.000000e+00  0.000000e+00
# 25%     2.429760e+05   5.360000e+02  8.548000e+03  6.700000e+01
# 50%     5.911560e+05   1.483000e+03  2.503000e+04  3.080000e+02
# 75%     1.512881e+06   4.339000e+03  7.838250e+04  1.086000e+03
# max     2.963142e+08   6.939302e+06  1.646425e+07  1.234147e+07

# %%
# data types for engagement_df

engagement_df.dtypes
# Out:
# cat_codes        object
# country          object
# channelTitle     object
# title            object
# view_count        int64
# comment_count     int64
# likes             int64
# dislikes          int64
# dtype: object

# %%
# a look into engagement_df

engagement_df.groupby(['country']).agg(['min', 'max', 'mean', 'sum', 'size']).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_069de_row0_col0,#T_069de_row0_col5,#T_069de_row0_col10,#T_069de_row0_col15,#T_069de_row1_col0,#T_069de_row1_col5,#T_069de_row1_col10,#T_069de_row1_col15,#T_069de_row2_col0,#T_069de_row2_col5,#T_069de_row2_col10,#T_069de_row2_col15,#T_069de_row3_col0,#T_069de_row3_col5,#T_069de_row3_col6,#T_069de_row3_col10,#T_069de_row3_col15,#T_069de_row4_col0,#T_069de_row4_col4,#T_069de_row4_col5,#T_069de_row4_col9,#T_069de_row4_col10,#T_069de_row4_col14,#T_069de_row4_col15,#T_069de_row4_col19,#T_069de_row5_col0,#T_069de_row5_col5,#T_069de_row5_col10,#T_069de_row5_col15,#T_069de_row5_col17,#T_069de_row5_col18,#T_069de_row6_col0,#T_069de_row6_col5,#T_069de_row6_col10,#T_069de_row6_col15,#T_069de_row7_col0,#T_069de_row7_col1,#T_069de_row7_col2,#T_069de_row7_col3,#T_069de_row7_col5,#T_069de_row7_col6,#T_069de_row7_col7,#T_069de_row7_col8,#T_069de_row7_col10,#T_069de_row7_col11,#T_069de_row7_col12,#T_069de_row7_col13,#T_069de_row7_col15,#T_069de_row7_col16,#T_069de_row8_col0,#T_069de_row8_col5,#T_069de_row8_col10,#T_069de_row8_col15,#T_069de_row9_col0,#T_069de_row9_col5,#T_069de_row9_col6,#T_069de_row9_col10,#T_069de_row9_col15,#T_069de_row10_col0,#T_069de_row10_col5,#T_069de_row10_col10,#T_069de_row10_col15{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_069de_row0_col1,#T_069de_row6_col1{
#             background-color:  #0f5aa3;
#             color:  #f1f1f1;
#         }#T_069de_row0_col2{
#             background-color:  #a4cce3;
#             color:  #000000;
#         }#T_069de_row0_col3,#T_069de_row10_col17{
#             background-color:  #9ac8e0;
#             color:  #000000;
#         }#T_069de_row0_col4,#T_069de_row0_col9,#T_069de_row0_col14,#T_069de_row0_col19,#T_069de_row2_col4,#T_069de_row2_col9,#T_069de_row2_col14,#T_069de_row2_col19,#T_069de_row4_col2,#T_069de_row4_col3,#T_069de_row4_col12,#T_069de_row4_col16,#T_069de_row4_col17,#T_069de_row4_col18,#T_069de_row5_col4,#T_069de_row5_col9,#T_069de_row5_col14,#T_069de_row5_col19,#T_069de_row6_col13,#T_069de_row8_col1,#T_069de_row8_col6,#T_069de_row8_col11,#T_069de_row9_col4,#T_069de_row9_col9,#T_069de_row9_col14,#T_069de_row9_col19,#T_069de_row10_col4,#T_069de_row10_col7,#T_069de_row10_col8,#T_069de_row10_col9,#T_069de_row10_col14,#T_069de_row10_col19{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_069de_row0_col6,#T_069de_row1_col3,#T_069de_row1_col12,#T_069de_row6_col6{
#             background-color:  #08519c;
#             color:  #f1f1f1;
#         }#T_069de_row0_col7{
#             background-color:  #5da5d1;
#             color:  #000000;
#         }#T_069de_row0_col8{
#             background-color:  #5ca4d0;
#             color:  #000000;
#         }#T_069de_row0_col11,#T_069de_row6_col11{
#             background-color:  #0a549e;
#             color:  #f1f1f1;
#         }#T_069de_row0_col12{
#             background-color:  #519ccc;
#             color:  #000000;
#         }#T_069de_row0_col13{
#             background-color:  #4e9acb;
#             color:  #000000;
#         }#T_069de_row0_col16,#T_069de_row2_col16,#T_069de_row3_col16,#T_069de_row9_col16{
#             background-color:  #f6faff;
#             color:  #000000;
#         }#T_069de_row0_col17,#T_069de_row2_col7{
#             background-color:  #d2e3f3;
#             color:  #000000;
#         }#T_069de_row0_col18{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }#T_069de_row1_col1,#T_069de_row4_col1,#T_069de_row10_col1{
#             background-color:  #2a7ab9;
#             color:  #000000;
#         }#T_069de_row1_col2{
#             background-color:  #135fa7;
#             color:  #f1f1f1;
#         }#T_069de_row1_col4,#T_069de_row1_col9,#T_069de_row1_col14,#T_069de_row1_col19,#T_069de_row3_col4,#T_069de_row3_col9,#T_069de_row3_col14,#T_069de_row3_col19,#T_069de_row6_col12{
#             background-color:  #08326e;
#             color:  #f1f1f1;
#         }#T_069de_row1_col6,#T_069de_row4_col6,#T_069de_row10_col6{
#             background-color:  #1967ad;
#             color:  #f1f1f1;
#         }#T_069de_row1_col7,#T_069de_row1_col8,#T_069de_row10_col13{
#             background-color:  #08509b;
#             color:  #f1f1f1;
#         }#T_069de_row1_col11,#T_069de_row10_col11{
#             background-color:  #2070b4;
#             color:  #f1f1f1;
#         }#T_069de_row1_col13{
#             background-color:  #084e98;
#             color:  #f1f1f1;
#         }#T_069de_row1_col16,#T_069de_row5_col16,#T_069de_row6_col16,#T_069de_row8_col16,#T_069de_row10_col16{
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_069de_row1_col17{
#             background-color:  #92c4de;
#             color:  #000000;
#         }#T_069de_row1_col18{
#             background-color:  #89bedc;
#             color:  #000000;
#         }#T_069de_row2_col1,#T_069de_row3_col12{
#             background-color:  #85bcdc;
#             color:  #000000;
#         }#T_069de_row2_col2{
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }#T_069de_row2_col3{
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }#T_069de_row2_col6{
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }#T_069de_row2_col8{
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }#T_069de_row2_col11{
#             background-color:  #4d99ca;
#             color:  #000000;
#         }#T_069de_row2_col12,#T_069de_row8_col13{
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }#T_069de_row2_col13{
#             background-color:  #cee0f2;
#             color:  #000000;
#         }#T_069de_row2_col17{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_069de_row2_col18{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_069de_row3_col1{
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }#T_069de_row3_col2{
#             background-color:  #87bddc;
#             color:  #000000;
#         }#T_069de_row3_col3{
#             background-color:  #7ab6d9;
#             color:  #000000;
#         }#T_069de_row3_col7,#T_069de_row8_col2{
#             background-color:  #9fcae1;
#             color:  #000000;
#         }#T_069de_row3_col8,#T_069de_row8_col3{
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }#T_069de_row3_col11{
#             background-color:  #84bcdb;
#             color:  #000000;
#         }#T_069de_row3_col13{
#             background-color:  #81badb;
#             color:  #000000;
#         }#T_069de_row3_col17{
#             background-color:  #c7dbef;
#             color:  #000000;
#         }#T_069de_row3_col18{
#             background-color:  #c2d9ee;
#             color:  #000000;
#         }#T_069de_row4_col7{
#             background-color:  #084f99;
#             color:  #f1f1f1;
#         }#T_069de_row4_col8,#T_069de_row4_col11{
#             background-color:  #1663aa;
#             color:  #f1f1f1;
#         }#T_069de_row4_col13,#T_069de_row5_col1{
#             background-color:  #084082;
#             color:  #f1f1f1;
#         }#T_069de_row5_col2,#T_069de_row9_col1{
#             background-color:  #ccdff1;
#             color:  #000000;
#         }#T_069de_row5_col3{
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }#T_069de_row5_col6,#T_069de_row5_col11{
#             background-color:  #083d7f;
#             color:  #f1f1f1;
#         }#T_069de_row5_col7{
#             background-color:  #c3daee;
#             color:  #000000;
#         }#T_069de_row5_col8{
#             background-color:  #c1d9ed;
#             color:  #000000;
#         }#T_069de_row5_col12{
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }#T_069de_row5_col13{
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }#T_069de_row6_col2{
#             background-color:  #3d8dc4;
#             color:  #000000;
#         }#T_069de_row6_col3,#T_069de_row9_col7,#T_069de_row9_col8{
#             background-color:  #3282be;
#             color:  #000000

# %%
# engagement_df user behavior by country

engagement_df.groupby(['country']).sum().sort_values('view_count', ascending = False).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_cdfbd_row0_col0,#T_cdfbd_row0_col3,#T_cdfbd_row1_col1,#T_cdfbd_row4_col2{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_cdfbd_row0_col1{
#             background-color:  #1663aa;
#             color:  #f1f1f1;
#         }#T_cdfbd_row0_col2{
#             background-color:  #084082;
#             color:  #f1f1f1;
#         }#T_cdfbd_row1_col0{
#             background-color:  #084c95;
#             color:  #f1f1f1;
#         }#T_cdfbd_row1_col2,#T_cdfbd_row2_col1{
#             background-color:  #08509b;
#             color:  #f1f1f1;
#         }#T_cdfbd_row1_col3{
#             background-color:  #8fc2de;
#             color:  #000000;
#         }#T_cdfbd_row2_col0{
#             background-color:  #08519c;
#             color:  #f1f1f1;
#         }#T_cdfbd_row2_col2{
#             background-color:  #084e98;
#             color:  #f1f1f1;
#         }#T_cdfbd_row2_col3{
#             background-color:  #89bedc;
#             color:  #000000;
#         }#T_cdfbd_row3_col0{
#             background-color:  #2979b9;
#             color:  #000000;
#         }#T_cdfbd_row3_col1,#T_cdfbd_row4_col0{
#             background-color:  #3282be;
#             color:  #000000;
#         }#T_cdfbd_row3_col2{
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }#T_cdfbd_row3_col3{
#             background-color:  #afd1e7;
#             color:  #000000;
#         }#T_cdfbd_row4_col1{
#             background-color:  #083776;
#             color:  #f1f1f1;
#         }#T_cdfbd_row4_col3{
#             background-color:  #a3cce3;
#             color:  #000000;
#         }#T_cdfbd_row5_col0{
#             background-color:  #7ab6d9;
#             color:  #000000;
#         }#T_cdfbd_row5_col1,#T_cdfbd_row7_col0{
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }#T_cdfbd_row5_col2{
#             background-color:  #81badb;
#             color:  #000000;
#         }#T_cdfbd_row5_col3{
#             background-color:  #c2d9ee;
#             color:  #000000;
#         }#T_cdfbd_row6_col0{
#             background-color:  #9ac8e0;
#             color:  #000000;
#         }#T_cdfbd_row6_col1{
#             background-color:  #5ca4d0;
#             color:  #000000;
#         }#T_cdfbd_row6_col2{
#             background-color:  #4e9acb;
#             color:  #000000;
#         }#T_cdfbd_row6_col3{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }#T_cdfbd_row7_col1{
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }#T_cdfbd_row7_col2{
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }#T_cdfbd_row7_col3{
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }#T_cdfbd_row8_col0{
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }#T_cdfbd_row8_col1{
#             background-color:  #c1d9ed;
#             color:  #000000;
#         }#T_cdfbd_row8_col2{
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }#T_cdfbd_row8_col3,#T_cdfbd_row10_col0,#T_cdfbd_row10_col1,#T_cdfbd_row10_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_cdfbd_row9_col0{
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }#T_cdfbd_row9_col1{
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }#T_cdfbd_row9_col2{
#             background-color:  #cee0f2;
#             color:  #000000;
#         }#T_cdfbd_row9_col3{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_cdfbd_row10_col3{
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }</style><table id="T_cdfbd_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >view_count</th>        <th class="col_heading level0 col1" >comment_count</th>        <th class="col_heading level0 col2" >likes</th>        <th class="col_heading level0 col3" >dislikes</th>    </tr>    <tr>        <th class="index_name level0" >country</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cdfbd_level0_row0" class="row_heading level0 row0" >India</th>
#                         <td id="T_cdfbd_row0_col0" class="data row0 col0" >351523987383</td>
#                         <td id="T_cdfbd_row0_col1" class="data row0 col1" >1291682696</td>
#                         <td id="T_cdfbd_row0_col2" class="data row0 col2" >18330309320</td>
#                         <td id="T_cdfbd_row0_col3" class="data row0 col3" >586291551</td>
#             </tr>
#             <tr>
#                         <th id="T_cdfbd_level0_row1" class="row_heading level0 row1" >United States</th>
#                         <td id="T_cdfbd_row1_col0" class="data row1 col0" >322593733707</td>
#                         <td id="T_cdfbd_row1_col1" class="data row1 col1" >1462358645</td>
#                         <td id="T_cdfbd_row1_col2" class="data row1 col2" >17499894159</td>
#                         <td id="T_cdfbd_row1_col3" class="data row1 col3" >304879045</td>
#             </tr>
#             <tr>
#                         <th id="T_cdfbd_level0_row2" class="row_heading level0 row2" >Canada</th>
#                         <td id="T_cdfbd_row2_col0" class="data row2 col0" >317900843626</td>
#                         <td id="T_cdfbd_row2_col1" class="data row2 col1" >1355824636</td>
#                         <td id="T_cdfbd_row2_col2" class="data row2 col2" >17597854570</td>
#                         <td id="T_cdfbd_row2_col3" class="data row2 col3" >313710368</td>
#             </tr>
#             <tr>
#                         <th id="T_cdfbd_level0_row3" class="row_heading level0 row3" >United Kingdom</th>
#                         <td id="T_cdfbd_row3_col0" class="data row3 col0" >276691720394</td>
#                         <td id="T_cdfbd_row3_col1" class="data row3 col1" >1188564744</td>
#                         <td id="T_cdfbd_row3_col2" class="data row3 col2" >15167993334</td>
#                         <td id="T_cdfbd_row3_col3" class="data row3 col3" >262210836</td>
#             </tr>
#             <tr>
#                         <th id="T_cdfbd_level0_row4" class="row_heading level0 row4" >Mexico</th>
#                         <td id="T_cdfbd_row4_col0" class="data row4 col0" >266975488862</td>
#                         <td id="T_cdfbd_row4_col1" class="data row4 col1" >1437410941</td>
#                         <td id="T_cdfbd_row4_col2" class="data row4 col2" >19108027382</td>
#                         <td id="T_cdfbd_row4_col3" class="data row4 col3" >281972163</td>
#             </tr>
#             <tr>
#                         <th id="T_cdfbd_level0_row5" class="row_heading level0 row5" >Germany</th>
#                         <td id="T_cdfbd_row5_col0" class="data row5 col0" >207807461037</td>
#                         <td id="T_cdfbd_row5_col1" class="data row5 col1" >919990543</td>
#                         <td id="T_cdfbd_row5_col2" class="data row5 col2" >11802812476</td>
#                         <td id="T_cdfbd_row5_col3" class="data row5 col3" >235373422</td>
#             </tr>
#             <tr>
#                         <th id="T_cdfbd_level0_row6" class="row_heading level0 row6" >Brazil</th>
#                         <td id="T_cdfbd_row6_col0" class="data row6 col0" >186266820301</td>
#                         <td id="T_cdfbd_row6_col1" class="data row6 col1" >1066034413</td>
#                         <td id="T_cdfbd_row6_col2" class="data row6 col2" >13685254413</td>
#                         <td id="T_cdfbd_row6_col3" class="data row6 col3" >205323913</td>
#             </tr>
#             <tr>
#                         <th id="T_cdfbd_level0_row7" class="row_heading level0 row7" >South Korea</th>
#                         <td id="T_cdfbd_row7_col0" class="data row7 col0" >185639031288</td>
#                         <td id="T_cdfbd_row7_col1" class="data row7 col1" >1068266707</td>

# %%
# engagement_df user behavior by category

engagement_df.groupby('cat_codes').sum().sort_values('view_count', ascending = False).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_184fd_row0_col0,#T_184fd_row0_col1,#T_184fd_row0_col2,#T_184fd_row0_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_184fd_row1_col0{
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#         }#T_184fd_row1_col1{
#             background-color:  #bfd8ed;
#             color:  #000000;
#         }#T_184fd_row1_col2{
#             background-color:  #519ccc;
#             color:  #000000;
#         }#T_184fd_row1_col3{
#             background-color:  #2979b9;
#             color:  #000000;
#         }#T_184fd_row2_col0{
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }#T_184fd_row2_col1{
#             background-color:  #deebf7;
#             color:  #000000;
#         }#T_184fd_row2_col2{
#             background-color:  #c9ddf0;
#             color:  #000000;
#         }#T_184fd_row2_col3{
#             background-color:  #cddff1;
#             color:  #000000;
#         }#T_184fd_row3_col0{
#             background-color:  #bed8ec;
#             color:  #000000;
#         }#T_184fd_row3_col1{
#             background-color:  #e4eff9;
#             color:  #000000;
#         }#T_184fd_row3_col2{
#             background-color:  #caddf0;
#             color:  #000000;
#         }#T_184fd_row3_col3{
#             background-color:  #bcd7eb;
#             color:  #000000;
#         }#T_184fd_row4_col0{
#             background-color:  #d2e3f3;
#             color:  #000000;
#         }#T_184fd_row4_col1,#T_184fd_row5_col1,#T_184fd_row7_col3,#T_184fd_row8_col0,#T_184fd_row9_col0,#T_184fd_row9_col3{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_184fd_row4_col2,#T_184fd_row7_col0{
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }#T_184fd_row4_col3{
#             background-color:  #e3eef9;
#             color:  #000000;
#         }#T_184fd_row5_col0,#T_184fd_row5_col3{
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }#T_184fd_row5_col2{
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }#T_184fd_row6_col0{
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }#T_184fd_row6_col1{
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }#T_184fd_row6_col2{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_184fd_row6_col3{
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }#T_184fd_row7_col1,#T_184fd_row8_col1,#T_184fd_row10_col3{
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }#T_184fd_row7_col2,#T_184fd_row10_col0{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_184fd_row8_col2,#T_184fd_row10_col1{
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_184fd_row8_col3{
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }#T_184fd_row9_col1,#T_184fd_row11_col2,#T_184fd_row11_col3{
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }#T_184fd_row9_col2,#T_184fd_row10_col2{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_184fd_row11_col0{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_184fd_row11_col1,#T_184fd_row12_col0,#T_184fd_row13_col0{
#             background-color:  #f6faff;
#             color:  #000000;
#         }#T_184fd_row12_col1,#T_184fd_row12_col2,#T_184fd_row12_col3,#T_184fd_row13_col1,#T_184fd_row13_col2,#T_184fd_row13_col3,#T_184fd_row14_col0,#T_184fd_row14_col1,#T_184fd_row14_col2,#T_184fd_row14_col3{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_184fd_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >view_count</th>        <th class="col_heading level0 col1" >comment_count</th>        <th class="col_heading level0 col2" >likes</th>        <th class="col_heading level0 col3" >dislikes</th>    </tr>    <tr>        <th class="index_name level0" >cat_codes</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_184fd_level0_row0" class="row_heading level0 row0" >Music</th>
#                         <td id="T_184fd_row0_col0" class="data row0 col0" >823967270913</td>
#                         <td id="T_184fd_row0_col1" class="data row0 col1" >6954497302</td>
#                         <td id="T_184fd_row0_col2" class="data row0 col2" >57495279379</td>
#                         <td id="T_184fd_row0_col3" class="data row0 col3" >965307499</td>
#             </tr>
#             <tr>
#                         <th id="T_184fd_level0_row1" class="row_heading level0 row1" >Entertainment</th>
#                         <td id="T_184fd_row1_col0" class="data row1 col0" >609912293964</td>
#                         <td id="T_184fd_row1_col1" class="data row1 col1" >1905616801</td>
#                         <td id="T_184fd_row1_col2" class="data row1 col2" >33436526467</td>
#                         <td id="T_184fd_row1_col3" class="data row1 col3" >696088830</td>
#             </tr>
#             <tr>
#                         <th id="T_184fd_level0_row2" class="row_heading level0 row2" >Gaming</th>
#                         <td id="T_184fd_row2_col0" class="data row2 col0" >231908134977</td>
#                         <td id="T_184fd_row2_col1" class="data row2 col1" >902091374</td>
#                         <td id="T_184fd_row2_col2" class="data row2 col2" >13647112752</td>
#                         <td id="T_184fd_row2_col3" class="data row2 col3" >209948776</td>
#             </tr>
#             <tr>
#                         <th id="T_184fd_level0_row3" class="row_heading level0 row3" >People & Blogs</th>
#                         <td id="T_184fd_row3_col0" class="data row3 col0" >227846858465</td>
#                         <td id="T_184fd_row3_col1" class="data row3 col1" >681737956</td>
#                         <td id="T_184fd_row3_col2" class="data row3 col2" >13512534786</td>
#                         <td id="T_184fd_row3_col3" class="data row3 col3" >276086338</td>
#             </tr>
#             <tr>
#                         <th id="T_184fd_level0_row4" class="row_heading level0 row4" >Sports</th>
#                         <td id="T_184fd_row4_col0" class="data row4 col0" >159793346077</td>
#                         <td id="T_184fd_row4_col1" class="data row4 col1" >327891649</td>
#                         <td id="T_184fd_row4_col2" class="data row4 col2" >4342958166</td>
#                         <td id="T_184fd_row4_col3" class="data row4 col3" >99844984</td>
#             </tr>
#             <tr>
#                         <th id="T_184fd_level0_row5" class="row_heading level0 row5" >Comedy</th>
#                         <td id="T_184fd_row5_col0" class="data row5 col0" >129627959416</td>
#                         <td id="T_184fd_row5_col1" class="data row5 col1" >366689790</td>
#                         <td id="T_184fd_row5_col2" class="data row5 col2" >8785908590</td>
#                         <td id="T_184fd_row5_col3" class="data row5 col3" >151389732</td>
#             </tr>
#             <tr>
#                         <th id="T_184fd_level0_row6" class="row_heading level0 row6" >Science & Technology</th>
#                         <td id="T_184fd_row6_col0" class="data row6 col0" >69282540198</td>
#                         <td id="T_184fd_row6_col1" class="data row6 col1" >181105854</td>
#                         <td id="T_184fd_row6_col2" class="data row6 col2" >3154188558</td>
#                         <td id="T_184fd_row6_col3" class="data row6 col3" >74517994</td>
#             </tr>
#             <tr>
#                         <th id="T_184fd_level0_row7" class="row_heading level0 row7" >Film & Animation</th>
#                         <td id="T_184fd_row7_col0" class="data row7 col0" >62485726170</td>

# %%
# dataframe for data set properties (Main Dash Page)

dash_df = main_df[['cat_codes', 'country', 'channelTitle', 'title', 'view_count', 'trending_date', 'publishedAt']]
dash_df.head()
# Out:
#         cat_codes        country   channelTitle  \
# 0  People & Blogs  United States       Brawadis
# 1          Gaming  United States   Apex Legends
# 2   Entertainment  United States  jacksepticeye
# 3           Music  United States            XXL
# 4   Howto & Style  United States       Mr. Kate
#
#                                                title  view_count  \
# 0                 I ASKED HER TO BE MY GIRLFRIEND...     1514614
# 1  Apex Legends | Stories from the Outlands – “Th...     2381688
# 2  I left youtube for a month and THIS is what ha...     2038853
# 3  XXL 2020 Freshman Class Revealed - Official An...      496771
# 4  Ultimate DIY Home Movie Theater for The LaBran...     1123889
#
#           trending_date           publishedAt
# 0  2020-08-12T00:00:00Z  2020-08-11T19:20:14Z
# 1  2020-08-12T00:00:00Z  2020-08-11T17:00:10Z
# 2  2020-08-12T00:00:00Z  2020-08-11T16:34:06Z
# 3  2020-08-12T00:00:00Z  2020-08-11T16:38:55Z
# 4  2020-08-12T00:00:00Z  2020-08-11T15:10:05Z

# %%
# data types for dash_df

dash_df.dtypes
# Out:
# cat_codes        object
# country          object
# channelTitle     object
# title            object
# view_count        int64
# trending_date    object
# publishedAt      object
# dtype: object

# %%
histo_df = dash_df.groupby('trending_date').sum().sort_values('trending_date')#.style.background_gradient(cmap='Blues')
histo_df.reset_index()
histo_df
# Out:
#                       view_count
# trending_date
# 2020-08-12T00:00:00Z  3337710145
# 2020-08-13T00:00:00Z  3352807149
# 2020-08-14T00:00:00Z  3323703533
# 2020-08-15T00:00:00Z  3557499287
# 2020-08-16T00:00:00Z  3516256748
# ...                          ...
# 2022-03-22T00:00:00Z  4474236858
# 2022-03-23T00:00:00Z  4080504662
# 2022-03-24T00:00:00Z  4182742555
# 2022-03-25T00:00:00Z  4030151477
# 2022-03-26T00:00:00Z  3853444033
#
# [576 rows x 1 columns]

# %%
fig = px.bar(histo_df, x=histo_df.index, y = 'view_count')
fig.show()
# Out:
# <div>                            <div id="545b8424-afef-4731-a704-10d4e701bcdf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("545b8424-afef-4731-a704-10d4e701bcdf")) {                    Plotly.newPlot(                        "545b8424-afef-4731-a704-10d4e701bcdf",                        [{"alignmentgroup":"True","hovertemplate":"trending_date=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2020-08-12T00:00:00Z","2020-08-13T00:00:00Z","2020-08-14T00:00:00Z","2020-08-15T00:00:00Z","2020-08-16T00:00:00Z","2020-08-17T00:00:00Z","2020-08-18T00:00:00Z","2020-08-19T00:00:00Z","2020-08-20T00:00:00Z","2020-08-21T00:00:00Z","2020-08-22T00:00:00Z","2020-08-23T00:00:00Z","2020-08-24T00:00:00Z","2020-08-25T00:00:00Z","2020-08-26T00:00:00Z","2020-08-27T00:00:00Z","2020-08-28T00:00:00Z","2020-08-29T00:00:00Z","2020-08-30T00:00:00Z","2020-08-31T00:00:00Z","2020-09-01T00:00:00Z","2020-09-02T00:00:00Z","2020-09-03T00:00:00Z","2020-09-04T00:00:00Z","2020-09-05T00:00:00Z","2020-09-06T00:00:00Z","2020-09-07T00:00:00Z","2020-09-08T00:00:00Z","2020-09-09T00:00:00Z","2020-09-10T00:00:00Z","2020-09-11T00:00:00Z","2020-09-12T00:00:00Z","2020-09-13T00:00:00Z","2020-09-14T00:00:00Z","2020-09-15T00:00:00Z","2020-09-16T00:00:00Z","2020-09-17T00:00:00Z","2020-09-18T00:00:00Z","2020-09-19T00:00:00Z","2020-09-20T00:00:00Z","2020-09-21T00:00:00Z","2020-09-22T00:00:00Z","2020-09-23T00:00:00Z","2020-09-24T00:00:00Z","2020-09-25T00:00:00Z","2020-09-26T00:00:00Z","2020-09-27T00:00:00Z","2020-09-28T00:00:00Z","2020-09-29T00:00:00Z","2020-09-30T00:00:00Z","2020-10-01T00:00:00Z","2020-10-02T00:00:00Z","2020-10-03T00:00:00Z","2020-10-04T00:00:00Z","2020-10-05T00:00:00Z","2020-10-06T00:00:00Z","2020-10-07T00:00:00Z","2020-10-08T00:00:00Z","2020-10-09T00:00:00Z","2020-10-10T00:00:00Z","2020-10-11T00:00:00Z","2020-10-12T00:00:00Z","2020-10-13T00:00:00Z","2020-10-14T00:00:00Z","2020-10-15T00:00:00Z","2020-10-16T00:00:00Z","2020-10-17T00:00:00Z","2020-10-18T00:00:00Z","2020-10-19T00:00:00Z","2020-10-20T00:00:00Z","2020-10-21T00:00:00Z","2020-10-22T00:00:00Z","2020-10-23T00:00:00Z","2020-10-24T00:00:00Z","2020-10-25T00:00:00Z","2020-10-26T00:00:00Z","2020-10-27T00:00:00Z","2020-10-29T00:00:00Z","2020-10-30T00:00:00Z","2020-10-31T00:00:00Z","2020-11-01T00:00:00Z","2020-11-02T00:00:00Z","2020-11-03T00:00:00Z","2020-11-04T00:00:00Z","2020-11-05T00:00:00Z","2020-11-06T00:00:00Z","2020-11-07T00:00:00Z","2020-11-08T00:00:00Z","2020-11-09T00:00:00Z","2020-11-10T00:00:00Z","2020-11-11T00:00:00Z","2020-11-12T00:00:00Z","2020-11-13T00:00:00Z","2020-11-14T00:00:00Z","2020-11-15T00:00:00Z","2020-11-16T00:00:00Z","2020-11-17T00:00:00Z","2020-11-18T00:00:00Z","2020-11-19T00:00:00Z","2020-11-20T00:00:00Z","2020-11-21T00:00:00Z","2020-11-23T00:00:00Z","2020-11-24T00:00:00Z","2020-11-25T00:00:00Z","2020-11-26T00:00:00Z","2020-11-27T00:00:00Z","2020-11-28T00:00:00Z","2020-11-29T00:00:00Z","2020-11-30T00:00:00Z","2020-12-01T00:00:00Z","2020-12-02T00:00:00Z","2020-12-03T00:00:00Z","2020-12-04T00:00:00Z","2020-12-05T00:00:00Z","2020-12-07T00:00:00Z","2020-12-08T00:00:00Z","2020-12-09T00:00:00Z","2020-12-10T00:00:00Z","2020-12-11T00:00:00Z","2020-12-12T00:00:00Z","2020-12-13T00:00:00Z","2020-12-14T00:00:00Z","2020-12-15T00:00:00Z","2020-12-16T00:00:00Z","2020-12-17T00:00:00Z","2020-12-18T00:00:00Z","2020-12-19T00:00:00Z","2020-12-20T00:00:00Z","2020-12-21T00:00:00Z","2020-12-22T00:00:00Z","2020-12-23T00:00:00Z","2020-12-24T00:00:00Z","2020-12-25T00:00:00Z","2020-12-26T00:00:00Z","2020-12-27T00:00:00Z","2020-12-28T00:00:00Z","2020-12-29T00:00:00Z","2020-12-31T00:00:00Z","2021-01-01T00:00:00Z","2021-01-02T00:0 ...
