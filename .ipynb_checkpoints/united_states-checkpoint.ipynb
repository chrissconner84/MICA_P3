# %%
#dependencies

from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

import seaborn as sns
# %matplotlib inline

# %%
# Read in csv's

temp_us = "..//practice_sources/US_youtube_trending_data.csv"


us_df = pd.read_csv(temp_us)

# %%
# Add country string column

us_df['country'] = 'United States'

# %%
# Updating categoryId column with corresponding string for all csv's

category_codes = {
    "1":'Film & Animation',
    "2":'Autos & Vehicles',
    "10":'Music',
    "15":'Pets & Animals',
    "17":'Sports',
    "18":'Short Movies',
    "19":'Travel & Events',
    "20":'Gaming',
    "21":'Videoblogging',
    "22":'People & Blogs',
    "23":'Comedy',
    "24":'Entertainment',
    "25":'News & Politics',
    "26":'Howto & Style',
    "27":'Education',
    "28":'Science & Technology',
    "29":'Nonprofits & Activism',
    "30":'Movies',
    "31":'Anime/Animation',
    "32":'Action/Adventure',
    "33":'Classics',
    "34":'Comedy',
    "35":'Documentary',
    "36":'Drama',
    "37":'Family',
    "38":'Foreign',
    "39":'Horror',
    "40":'Sci-Fi/Fantasy',
    "41":'Thriller',
    "42":'Shorts',
    "43":'Shows',
    "44":'Trailers'
}

cat_code = us_df["categoryId"].map(lambda x: category_codes[str(x)])
us_df['cat_codes'] = cat_code

# %%
# drop uneeded columns

us_df.drop(['comments_disabled', 'ratings_disabled'], axis = 1, inplace = True)

# %%
# drop uneeded columns

us_df.drop(['title', 'tags'], axis = 1, inplace = True)

# %%
us_df
# Out:
#            video_id           publishedAt                 channelId  \
# 0       3C66w5Z0ixs  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg
# 1       M9Pmf9AB4Mo  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A
# 2       J78aPJ3VyNs  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g
# 3       kXLn3HkpjaA  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg
# 4       VIUo6yapDbc  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A
# ...             ...                   ...                       ...
# 119186  vDqlhp2TfYE  2022-03-20T01:00:38Z  UC3L9XPe0_FGfRG-CMGtBvFg
# 119187  boz7vfxsy0k  2022-03-20T22:00:10Z  UCqGoMWYphRN_r9HB-0JDH2g
# 119188  iKD14Sr2CUI  2022-03-19T18:45:45Z  UC5p_l5ZeB_wGjO_yDXwiqvw
# 119189  7OmeKVKim2M  2022-03-20T06:27:12Z  UCurvRE5fGcdUgCYWgh-BDsg
# 119190  fMXEX_tJdLk  2022-03-21T22:38:42Z  UCDit-dp02_yDsn-zDxm7W4A
#
#           channelTitle  categoryId         trending_date  view_count   likes  \
# 0             Brawadis          22  2020-08-12T00:00:00Z     1514614  156908
# 1         Apex Legends          20  2020-08-12T00:00:00Z     2381688  146739
# 2        jacksepticeye          24  2020-08-12T00:00:00Z     2038853  353787
# 3                  XXL          10  2020-08-12T00:00:00Z      496771   23251
# 4             Mr. Kate          26  2020-08-12T00:00:00Z     1123889   45802
# ...                ...         ...                   ...         ...     ...
# 119186  JxmyHighroller          17  2022-03-26T00:00:00Z     1455302   67072
# 119187  KalaniBallFree          17  2022-03-26T00:00:00Z      450604   28122
# 119188      TommyInnit          20  2022-03-26T00:00:00Z     2162337  208496
# 119189     DAZN Boxing          17  2022-03-26T00:00:00Z      301940    5563
# 119190   Jooj Natu ENG          24  2022-03-26T00:00:00Z     2317110  245351
#
#         dislikes  comment_count  \
# 0           5855          35313
# 1           2794          16549
# 2           2628          40221
# 3           1856           7647
# 4            964           2196
# ...          ...            ...
# 119186         0           3290
# 119187         0            300
# 119188         0           9696
# 119189         0           1199
# 119190         0            800
#
#                                         thumbnail_link  \
# 0       https://i.ytimg.com/vi/3C66w5Z0ixs/default.jpg
# 1       https://i.ytimg.com/vi/M9Pmf9AB4Mo/default.jpg
# 2       https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg
# 3       https://i.ytimg.com/vi/kXLn3HkpjaA/default.jpg
# 4       https://i.ytimg.com/vi/VIUo6yapDbc/default.jpg
# ...                                                ...
# 119186  https://i.ytimg.com/vi/vDqlhp2TfYE/default.jpg
# 119187  https://i.ytimg.com/vi/boz7vfxsy0k/default.jpg
# 119188  https://i.ytimg.com/vi/iKD14Sr2CUI/default.jpg
# 119189  https://i.ytimg.com/vi/7OmeKVKim2M/default.jpg
# 119190  https://i.ytimg.com/vi/fMXEX_tJdLk/default.jpg
#
#                                               description        country  \
# 0       SUBSCRIBE to BRAWADIS ▶ http://bit.ly/Subscrib...  United States
# 1       While running her own modding shop, Ramya Pare...  United States
# 2       I left youtube for a month and this is what ha...  United States
# 3       Subscribe to XXL → http://bit.ly/subscribe-xxl...  United States
# 4       Transforming The LaBrant Family's empty white ...  United States
# ...                                                   ...            ...
# 119186  New DraftKings players use promo code JXMYHIGH...  United States
# 119187                                                NaN  United States
# 119188  This was with 1,000 Subscribers, so if you wan...  United States
# 119189  March 19th, 2022 -- Alexis Rocha vs. Blair Cob...  United States
# 119190  This time the Producer's kid mom it's involved...  United States
#
#              cat_codes
# 0       People & Blogs
# 1               Gaming
# 2        Entertainment
# 3                Music
# 4        Howto & Style
# ...                ...
# 119186          Sports
# 119187          Sports
# 119188          Gaming
# 119189          Sports
# 119190   Entertainment
#
# [119191 rows x 14 columns]

# %%
us_df.to_csv("../project3_data_file/us.csv")
