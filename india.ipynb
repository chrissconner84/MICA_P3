# %%
#dependencies

from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

import seaborn as sns
# %matplotlib inline

# %%
# Read in csv's

temp_us = "..//practice_sources/in_youtube_trending_data.csv"
in_df = pd.read_csv(temp_us)

# Add country string column
in_df['country'] = 'India'

# %%
# Updating categoryId column with corresponding string for all csv's

category_codes = {
    "1":'Film & Animation',
    "2":'Autos & Vehicles',
    "10":'Music',
    "15":'Pets & Animals',
    "17":'Sports',
    "18":'Short Movies',
    "19":'Travel & Events',
    "20":'Gaming',
    "21":'Videoblogging',
    "22":'People & Blogs',
    "23":'Comedy',
    "24":'Entertainment',
    "25":'News & Politics',
    "26":'Howto & Style',
    "27":'Education',
    "28":'Science & Technology',
    "29":'Nonprofits & Activism',
    "30":'Movies',
    "31":'Anime/Animation',
    "32":'Action/Adventure',
    "33":'Classics',
    "34":'Comedy',
    "35":'Documentary',
    "36":'Drama',
    "37":'Family',
    "38":'Foreign',
    "39":'Horror',
    "40":'Sci-Fi/Fantasy',
    "41":'Thriller',
    "42":'Shorts',
    "43":'Shows',
    "44":'Trailers'
}

cat_code = in_df["categoryId"].map(lambda x: category_codes[str(x)])
in_df['cat_codes'] = cat_code

# %%
# drop uneeded columns

in_df.drop(['comments_disabled', 'ratings_disabled'], axis = 1, inplace = True)

# %%
# drop uneeded columns

in_df.drop(['title', 'tags'], axis = 1, inplace = True)

# %%
in_df.drop(['categoryId', 'description'], axis = 1, inplace = True)

# %%
in_df.dropna(inplace = True)

# %%
in_df
# Out:
#            video_id           publishedAt                 channelId  \
# 0       Iot0eF6EoNA  2020-08-12T04:31:41Z  UCGqvJPRcv7aVFun-eTsatcA
# 1       x-KbnJ9fvJc  2020-08-11T09:00:11Z  UCm9SZAl03Rev9sFwloCdz1g
# 2       KX06ksuS6Xo  2020-08-11T07:30:02Z  UCZRdNleCgW-BGUJf-bbjzQg
# 3       UsMRgnTcchY  2020-08-10T05:30:49Z  UCq-Fj5jknLsUf-MWSy4_brA
# 4       WNSEXJJhKTU  2020-08-11T05:30:13Z  UCye6Oz0mg46S362LwARGVcA
# ...             ...                   ...                       ...
# 113321  TQcNbotMAKQ  2022-03-22T05:30:03Z  UCLtCejNl8eAg4PO_9lf2TIg
# 113322  S6quidShYsk  2022-03-21T15:14:35Z  UCpXLDGcGtqkC7MIF5sKYU0w
# 113323  FordKr1XRWg  2022-03-22T08:41:36Z  UCMmMsJI54IsODpEsG08PsJA
# 113324  reMiZmHCTZE  2022-03-22T14:15:11Z  UCCMUnWvJyTEUunnygpTGfow
# 113325  2heUsL5T6Bk  2022-03-23T05:31:25Z  UCHGktfcQq2BY_8tGPHwvm7g
#
#           channelTitle         trending_date  view_count   likes  dislikes  \
# ...

# %%
in_df.to_csv("../project3_data_file/in.csv", index = False)
