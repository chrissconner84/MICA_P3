# %%
#dependencies

from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

import seaborn as sns
# %matplotlib inline

# %%
# Read in csv's

temp_us = "..//practice_sources/ca_youtube_trending_data.csv"
ca_df = pd.read_csv(temp_us)

# Add country string column
ca_df['country'] = 'Canada'

# %%
# Updating categoryId column with corresponding string for all csv's

category_codes = {
    "1":'Film & Animation',
    "2":'Autos & Vehicles',
    "10":'Music',
    "15":'Pets & Animals',
    "17":'Sports',
    "18":'Short Movies',
    "19":'Travel & Events',
    "20":'Gaming',
    "21":'Videoblogging',
    "22":'People & Blogs',
    "23":'Comedy',
    "24":'Entertainment',
    "25":'News & Politics',
    "26":'Howto & Style',
    "27":'Education',
    "28":'Science & Technology',
    "29":'Nonprofits & Activism',
    "30":'Movies',
    "31":'Anime/Animation',
    "32":'Action/Adventure',
    "33":'Classics',
    "34":'Comedy',
    "35":'Documentary',
    "36":'Drama',
    "37":'Family',
    "38":'Foreign',
    "39":'Horror',
    "40":'Sci-Fi/Fantasy',
    "41":'Thriller',
    "42":'Shorts',
    "43":'Shows',
    "44":'Trailers'
}

cat_code = ca_df["categoryId"].map(lambda x: category_codes[str(x)])
ca_df['cat_codes'] = cat_code
ca_df
# Out:
#            video_id                                              title  \
# 0       KX06ksuS6Xo  Diljit Dosanjh: CLASH (Official) Music Video |...
# 1       J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 2       M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 3       3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 4       VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...             ...                                                ...
# 119139  DfAEQnbjt2c      Guilty Gear -Strive- Starter Guide -Testament
# 119140  vqVjvvTn7OE                Did you know that in TENET… #shorts
# 119141  HSC3BheJuhU    【3D MV】「UnAlive」- Calliope Mori (Original Song)
# 119142  52qxVuZOuIM  RAPTORS at 76ERS | FULL GAME HIGHLIGHTS | Marc...
# 119143  pO5qI_RyXT0                   KOF XV DLC | OMEGA RUGAL｜Trailer
#
#                  publishedAt                 channelId  \
# 0       2020-08-11T07:30:02Z  UCZRdNleCgW-BGUJf-bbjzQg
# ...

# %%
# drop uneeded columns

ca_df.drop(['comments_disabled', 'ratings_disabled'], axis = 1, inplace = True)

# %%
# drop uneeded columns

ca_df.drop(['title', 'tags'], axis = 1, inplace = True)

# %%
ca_df.drop(['categoryId', 'description'], axis = 1, inplace = True)
ca_df.head()
# Out:
#       video_id           publishedAt                 channelId  \
# 0  KX06ksuS6Xo  2020-08-11T07:30:02Z  UCZRdNleCgW-BGUJf-bbjzQg
# 1  J78aPJ3VyNs  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g
# 2  M9Pmf9AB4Mo  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A
# 3  3C66w5Z0ixs  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg
# 4  VIUo6yapDbc  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A
#
#      channelTitle         trending_date  view_count   likes  dislikes  \
# 0  Diljit Dosanjh  2020-08-12T00:00:00Z     9140911  296541      6180
# 1   jacksepticeye  2020-08-12T00:00:00Z     2038853  353797      2628
# 2    Apex Legends  2020-08-12T00:00:00Z     2381688  146740      2794
# 3        Brawadis  2020-08-12T00:00:00Z     1514614  156914      5857
# 4        Mr. Kate  2020-08-12T00:00:00Z     1123889   45803       964
#
#    comment_count                                  thumbnail_link country  \
# 0          30059  https://i.ytimg.com/vi/KX06ksuS6Xo/default.jpg  Canada
# ...

# %%
ca_df.to_csv("../project3_data_file/ca.csv", index = False)
